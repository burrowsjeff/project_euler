# %% [markdown]
# # Project Euler - Problem 12
#
# ## Highly divisible triangular number
#
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
#
# * 1: 1
# * 3: 1,3
# * 6: 1,2,3,6
# * 10: 1,2,5,10
# * 15: 1,3,5,15
# * 21: 1,3,7,21
# * 28: 1,2,4,7,14,28
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %% [markdown]
# ## Plan of attack:
#
# I think the main components of the problem are:
# * Generate a list of triangle numbers
# * Find the factors of those triangle numbers
# * Check the length of the list of factors for each triangle numbers
#
# Problems I am not sure about yet:
# * How can I structure the loop so that the function stops when the len(factor_list) is greater than 499?
#     * Maybe something like "while len(factor_list) < 500:" and then just keep replacing factor_list so that when the while loop stops, the length will be the first number to generate a length of 500?
# * How can I generate new triangle numbers as I need them instead of up front and then iterate through them?
#     * Maybe store them as dictionary values so they have a position and a value, and then I can add the position to the previous value to generate a new triangle number?

# %% [markdown]
# ### First, let's start with the given list of example triangle numbers and see if we can get a while loop working for the given numbers

# %%
triangle_list = [1,3,6,10,15,21,28]
#triangle_list = [1,3]
tnum = 3
factor_list = [1,3]

#while len(factor_list) < 6:
#    triangle_list.append(tnum + triangle_list[-1])
    tnum = triangle_list[-1]
    for i in range(1,tnum):
        factor_list = [1]
        if tnum % i == 0:
            factor_list.append(i)
            i += 1
        else:
            i += 1

print('Triangle list:',triangle_list)
print('Last Triangle number:',tnum)
print('Last Triangle number\'s factor list:',factor_list)
# Out:
#   File "<ipython-input-1-ffbba8d3a410>", line 8
#     tnum = triangle_list[-1]
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### Well that didn't work. Let's try again:

# %%
triangle_list = [1,3,6,10,15,21,28]
tnum = 3
factor_list = [1,3]

for i in range(1,len(triangle_list)):
    tnum = triangle_list[i-len(triangle_list)]
    factor_list = []
    for t in range(1,tnum):
        if tnum % t == 0:
            factor_list.append(t)
    factor_list.append(tnum)
            
    print(tnum,'with factors',factor_list,)
# Out:
# 3 with factors [1, 3]
# 6 with factors [1, 2, 3, 6]
# 10 with factors [1, 2, 5, 10]
# 15 with factors [1, 3, 5, 15]
# 21 with factors [1, 3, 7, 21]
# 28 with factors [1, 2, 4, 7, 14, 28]

# %% [markdown]
# ### Okay, that works
#
# For a static input of triangle numbers anyway...
#
# Next, I'm going to try and iterate through a list of triangle numbers while the length of the factor list is less than 5 or 6.

# %% [markdown]
# tnum = 3
# factor_list = [1,3]
# a = 2
# t = 1
#
# while len(factor_list) < 6:
#     tnum = (a+1)+(a)+1
#     for t in range(t,tnum):
#         if tnum % t == 0:
#             factor_list.append(t)
#     factor_list.append(tnum)
#     a += 1
#     print('a=',a,'with tnum',tnum,factor_list)
